# %%
import sys
sys.path.append('../python/')
import asteriks as ak
import numpy as np
import matplotlib.pyplot as plt
import astropy.units as u
import pandas as pd
import os
from scipy.ndimage.filters import gaussian_filter1d
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = ak.Asteroid('1998 SN165', campaign=8, dir='/Volumes/cupertino/database/')

# %%
a.movie(42,'../output/movies/')
# Out:
# Finding background (lagged 0.5 days)
# 3853it [00:08, 440.83it/s]
# 1986 TPFs on source
# 3853it [00:10, 362.17it/s]
# Finding asteroid
# 3853it [00:11, 338.77it/s]
# Creating movie

# %%
plt.figure(figsize=(15,3))
plt.plot(a.time[a.cadence],a.f,zorder=0,alpha=0.5,ls='--',c='C3')
plt.scatter(a.time[a.cadence[a.ok]],a.f[a.ok],s=6,c='black',zorder=1)
plt.ylim(0,300)
# Out:
# (0, 300)
